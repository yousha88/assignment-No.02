# %%
# Assignment 02

# %%
import pandas as pd

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
pd.read_csv("data sheet.csv")
# Out:
#       Number of clicks on similar products  \
# 0                                       12
# 1                                        8
# 2                                       25
# 3                                        6
# 4                                       18
# ...                                    ...
# 1469                                     5
# 1470                                    37
# 1471                                    22
# 1472                                    40
# 1473                                    12
#
#       Number of similar products purchased so far  \
# 0                                               4
# 1                                               2
# 2                                              10
# 3                                               1
# 4                                               5
# ...                                           ...
# 1469                                            1
# ...

# %%
df= pd.read_csv("data sheet.csv")

# %%
df
# Out:
#       Number of clicks on similar products  \
# 0                                       12
# 1                                        8
# 2                                       25
# 3                                        6
# 4                                       18
# ...                                    ...
# 1469                                     5
# 1470                                    37
# 1471                                    22
# 1472                                    40
# 1473                                    12
#
#       Number of similar products purchased so far  \
# 0                                               4
# 1                                               2
# 2                                              10
# 3                                               1
# 4                                               5
# ...                                           ...
# 1469                                            1
# ...

# %%
# question no.01

# %%
df.head(6)
# Out:
#    Number of clicks on similar products  \
# 0                                    12
# 1                                     8
# 2                                    25
# 3                                     6
# 4                                    18
# 5                                     0
#
#    Number of similar products purchased so far  \
# 0                                            4
# 1                                            2
# 2                                           10
# 3                                            1
# 4                                            5
# 5                                            0
#
#    Average rating given to similar products  Gender  \
# 0                                       4.2    male
# 1                                       3.8  female
# 2                                       4.5  female
# 3                                       2.1  female
# 4                                       4.7    male
# ...

# %%
# question no.02

# %%
("shape:", df.shape)
# Out:
# ('shape:', (1474, 13))

# %%
("columns:", df.columns)
# Out:
# ('columns:',
#  Index(['Number of clicks on similar products',
#         'Number of similar products purchased so far',
#         'Average rating given to similar products', 'Gender',
#         'Median purchasing price (in rupees)', 'Rating of the product',
#         'Brand of the product', 'Customer review sentiment score (overall)',
#         'Price of the product', 'Holiday', 'Season', 'Geographical locations',
#         'Probability for the product to be recommended to the person'],
#        dtype='str'))

# %%
#question no.03

# %%
 (df.dtypes)
# Out:
# Number of clicks on similar products                             int64
# Number of similar products purchased so far                      int64
# Average rating given to similar products                       float64
# Gender                                                             str
# Median purchasing price (in rupees)                              int64
# Rating of the product                                          float64
# Brand of the product                                               str
# Customer review sentiment score (overall)                      float64
# Price of the product                                             int64
# Holiday                                                            str
# Season                                                             str
# Geographical locations                                             str
# Probability for the product to be recommended to the person    float64
# dtype: object

# %%
#question no.04

# %%
df.isnull().head(11)
# Out:
#     Number of clicks on similar products  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
# 5                                  False
# 6                                  False
# 7                                  False
# 8                                  False
# 9                                  False
# 10                                 False
#
#     Number of similar products purchased so far  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
# 5                                         False
# 6                                         False
# 7                                         False
# ...

# %%
#question no.05

# %%
df.dropna()
# Out:
#       Number of clicks on similar products  \
# 0                                       12
# 1                                        8
# 2                                       25
# 3                                        6
# 4                                       18
# ...                                    ...
# 1469                                     5
# 1470                                    37
# 1471                                    22
# 1472                                    40
# 1473                                    12
#
#       Number of similar products purchased so far  \
# 0                                               4
# 1                                               2
# 2                                              10
# 3                                               1
# 4                                               5
# ...                                           ...
# 1469                                            1
# ...

# %%
#question no.06

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates()
# Out:
#       Number of clicks on similar products  \
# 0                                       12
# 1                                        8
# 2                                       25
# 3                                        6
# 4                                       18
# ...                                    ...
# 1469                                     5
# 1470                                    37
# 1471                                    22
# 1472                                    40
# 1473                                    12
#
#       Number of similar products purchased so far  \
# 0                                               4
# 1                                               2
# 2                                              10
# 3                                               1
# 4                                               5
# ...                                           ...
# 1469                                            1
# ...

# %%
#question no.07

# %%
df.describe()
# Out:
#        Number of clicks on similar products  \
# count                           1018.000000
# mean                              21.397839
# std                               12.103449
# min                                0.000000
# 25%                               11.000000
# 50%                               20.000000
# 75%                               31.000000
# max                               55.000000
#
#        Number of similar products purchased so far  \
# count                                  1018.000000
# mean                                      9.017682
# std                                       5.740169
# min                                       0.000000
# 25%                                       4.000000
# 50%                                       8.000000
# 75%                                      14.000000
# max                                      24.000000
#
#        Average rating given to similar products  \
# ...

# %%
#question no.08

# %%
avg_price = df['Price of the product'].mean()
print("avrage price:",avg_price)
# Out:
# avrage price: 1334.9214145383105

# %%
#question no.09

# %%
max_value = df['Median purchasing price (in rupees)'].max()
min_value = df['Median purchasing price (in rupees)'].min()
print(f"max:{max_value}:,min:{min_value}")
# Out:
# max:19000:,min:100

# %%
#question no.10

# %%
df['Brand of the product'].value_counts()
# Out:
# Brand of the product
# Wildcraft                          74
# Manyavar Mohey                     58
# Pepperfry                          55
# Flying Machine                     52
# Patanjali Ayurved (Health Care)    50
# Lee                                46
# Lakme Ayurveda                     45
# Wakefit                            41
# Johnson & Johnson                  40
# Khadi Essentials                   34
# Pepe Jeans London                  33
# Kama Ayurveda                      32
# Max                                29
# PUMA                               25
# Head Hunters                       24
# Himalaya Liv.52                    24
# Sugar Cosmetics                    24
# The Moms Co.                       22
# Fastrack                           22
# Dettol                             21
# SleepyCat                          20
# Urban Ladder                       20
# AmazonBasics                       17
# Forest Essentials                  16
# ...

# %%
#question no.11

# %%
df.sort_values(by='Price of the product').head(10)
# Out:
#       Number of clicks on similar products  \
# 764                                     39
# 752                                     40
# 788                                     34
# 877                                      2
# 1061                                     5
# 1418                                    19
# 1424                                    14
# 1465                                    16
# 1411                                     7
# 84                                      10
#
#       Number of similar products purchased so far  \
# 764                                            15
# 752                                            16
# 788                                            13
# 877                                             0
# 1061                                            0
# 1418                                            5
# 1424                                            3
# 1465                                            5
# ...

# %%
#question no.12

# %%
df[df['Rating of the product'] > 4]
# Out:
#       Number of clicks on similar products  \
# 0                                       12
# 2                                       25
# 4                                       18
# 6                                       38
# 9                                       10
# ...                                    ...
# 1467                                    43
# 1468                                    21
# 1470                                    37
# 1471                                    22
# 1472                                    40
#
#       Number of similar products purchased so far  \
# 0                                               4
# 2                                              10
# 4                                               5
# 6                                              15
# 9                                               4
# ...                                           ...
# 1467                                           14
# ...

# %%
#question no.13

# %%
df['price difference'] = df['Price of the product'] - df['Median purchasing price (in rupees)']
print(df[['Price of the product', 'Median purchasing price (in rupees)']].head(10))
# Out:
#    Price of the product  Median purchasing price (in rupees)
# 0                   200                                  500
# 1                   300                                 3000
# 2                  1000                                  600
# 3                   300                                  100
# 4                   700                                 2000
# 5                  1000                                 1000
# 6                   700                                  700
# 7                   900                                 5000
# 8                   400                                  900
# 9                   200                                  300

# %%
#question no.14

# %%
gender_avg = df.groupby('Gender')['Price of the product'].mean()
print(gender_avg)
# Out:
# Gender
# female     783.638171
# male      1873.359223
# Name: Price of the product, dtype: float64

# %%
#question no.15

# %%
plt.hist(df['Price of the product'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Product Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
#Conclusion

# %%
# 1.data cleaning process removed null and duolicates value
# 2.observed that high rated product = 585 rows , 13 column
#3.observed that female = 783.638171  male = 1873.359223
#4.frequency are dicreasing when priceses are increasing
